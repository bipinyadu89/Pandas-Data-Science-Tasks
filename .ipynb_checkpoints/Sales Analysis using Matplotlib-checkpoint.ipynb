# %%
import pandas as pd
import os

# %%
from openpyxl import load_workbook

# %% [markdown]
# ### Select Data Source

# %%
files= os.listdir('./SalesAnalysis/Sales_Data')

# %% [markdown]
# ### Remove Unwanted Files

# %%
files=files[1:]

# %% [markdown]
# ## Merge Data from all files

# %%
all_data=pd.DataFrame()
for file in files:
    data=pd.read_csv('./SalesAnalysis/Sales_Data/'+file)
    all_data=pd.concat([all_data,data])

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Remove rows containing headings

# %%
all_data=all_data.loc[all_data['Quantity Ordered']!='Quantity Ordered']

# %% [markdown]
# # Question 1: What month has maximum Sales?

# %% [markdown]
# ### Extract Day and Month from Datetime column

# %%
all_data['Order Day']=pd.DatetimeIndex(all_data['Order Date']).day

all_data['Order Month']=pd.DatetimeIndex(all_data['Order Date']).month

all_data.dropna(how='all',inplace=True)

# %% [markdown]
# ## Create a Calculated Column of Sales

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']=pd.to_numeric(all_data['Price Each'])
all_data['Sales']=all_data['Quantity Ordered']*all_data['Price Each']

# %% [markdown]
# ### Best Sales Month

# %%
bsm=all_data.groupby('Order Month').sum()
bsm
# Out:
#              Quantity Ordered    Price Each  Order Day         Sales
# Order Month
# 1.0                     10903  1.811768e+06   155814.0  1.822257e+06
# 2.0                     13449  2.188885e+06   174408.0  2.202022e+06
# 3.0                     17005  2.791208e+06   241774.0  2.807100e+06
# 4.0                     20558  3.367671e+06   282960.0  3.390670e+06
# 5.0                     18667  3.135125e+06   264875.0  3.152607e+06
# 6.0                     15253  2.562026e+06   209880.0  2.577802e+06
# 7.0                     16072  2.632540e+06   227910.0  2.647776e+06
# 8.0                     13448  2.230345e+06   192315.0  2.244468e+06
# 9.0                     13109  2.084992e+06   180101.0  2.097560e+06
# 10.0                    22703  3.715555e+06   326141.0  3.736727e+06
# 11.0                    19798  3.180601e+06   272854.0  3.199603e+06
# 12.0                    28114  4.588415e+06   401453.0  4.613443e+06

# %%
bsm['Sales'].plot.bar()

# %% [markdown]
# # Question 2: What City has maximum Sales?

# %% [markdown]
# ### Extract City from Address
# Lets use apply function

# %%
all_data['City']=all_data['Purchase Address'].apply(lambda x: x.split(',')[1])

# %%
all_data['LPin']=all_data['Purchase Address'].apply(lambda x: x.split(',')[2]).str[-5:]

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Order Day  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       19.0
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215        7.0
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       12.0
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       12.0
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       30.0
#
#    Order Month   Sales          City   LPin
# 0          4.0   23.90        Dallas  75001
# 2          4.0   99.99        Boston  02215
# 3          4.0  600.00   Los Angeles  90001
# 4          4.0   11.99   Los Angeles  90001
# 5          4.0   11.99   Los Angeles  90001

# %%
all_data['Location']=all_data[['City','LPin']].apply(lambda x: " ".join(x),axis=1)

# %%
result=all_data.groupby('Location').sum().sort_values('Sales',ascending=False)

# %%
result
# Out:
#                       Quantity Ordered    Price Each  Order Day  Order Month  \
# Location
#  San Francisco 94016             50239  8.211462e+06   702669.0     315520.0
#  Los Angeles 90001               33289  5.421435e+06   469607.0     208325.0
#  New York City 10001             27932  4.635371e+06   392706.0     175741.0
#  Boston 02215                    22528  3.637410e+06   312376.0     141112.0
#  Atlanta 30301                   16602  2.779908e+06   234837.0     104794.0
#  Dallas 75001                    16730  2.752628e+06   234435.0     104620.0
#  Seattle 98101                   16553  2.733296e+06   229552.0     104941.0
#  Portland 97035                  11303  1.860558e+06   159233.0      70621.0
#  Austin 73301                    11153  1.809874e+06   156782.0      69829.0
#  Portland 04101                   2750  4.471893e+05    38288.0      17144.0
#
#                              Sales
# Location
#  San Francisco 94016  8.262204e+06
#  Los Angeles 90001    5.452571e+06
#  New York City 10001  4.664317e+06
#  Boston 02215         3.661642e+06
#  Atlanta 30301        2.795499e+06
#  Dallas 75001         2.767975e+06
#  Seattle 98101        2.747755e+06
#  Portland 97035       1.870732e+06
#  Austin 73301         1.819582e+06
#  Portland 04101       4.497583e+05

# %%
result['Sales'].plot.bar()

# %% [markdown]
# # Question 3: What time advertisements should display to maximize sales?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Order Day  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       19.0
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215        7.0
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       12.0
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       12.0
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       30.0
#
#    Order Month   Sales          City   LPin            Location
# 0          4.0   23.90        Dallas  75001        Dallas 75001
# 2          4.0   99.99        Boston  02215        Boston 02215
# 3          4.0  600.00   Los Angeles  90001   Los Angeles 90001
# 4          4.0   11.99   Los Angeles  90001   Los Angeles 90001
# 5          4.0   11.99   Los Angeles  90001   Los Angeles 90001

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
all_data['Order Time']=all_data['Order Date'].apply(lambda x: x.time().hour)

# %%
adtime=all_data.groupby('Order Time').sum()
adtime
# Out:
#             Quantity Ordered  Price Each  Order Day  Order Month       Sales
# Order Time
# 0                       4428   709296.70    62015.0      27554.0   713721.27
# 1                       2619   458490.00    37333.0      16657.0   460866.88
# 2                       1398   233833.64    19631.0       8507.0   234851.44
# 3                        928   144726.42    13430.0       5904.0   145757.89
# 4                        937   162058.18    13756.0       6148.0   162661.01
# 5                       1493   229621.21    21347.0       9301.0   230679.82
# 6                       2810   445000.11    39824.0      17539.0   448113.00
# 7                       4556   740568.11    63111.0      28850.0   744854.12
# 8                       7002  1185970.62    98078.0      43626.0  1192348.97
# 9                       9816  1628498.49   137512.0      60981.0  1639030.58
# 10                     12308  1932665.62   173128.0      76928.0  1944286.77
# 11                     14005  2288855.18   195901.0      87654.0  2300610.24
# 12                     14202  2299876.68   197231.0      89161.0  2316821.34
# 13                     13685  2139743.86   190415.0      85808.0  2155389.80
# 14                     12362  2072194.77   173264.0      77836.0  2083672.73
# 15                     11391  1931174.99   161441.0      72060.0  1941549.60
# 16                     11662  1892454.54   162579.0      72939.0  1904601.31
# 17                     12229  2116777.02   169311.0      77454.0  2129361.61
# 18                     13802  2207696.93   194087.0      86421.0  2219348.30
# 19                     14470  2398588.31   205868.0      91389.0  2412938.54
# 20                     13768  2268185.16   192147.0      86375.0  2281716.24
# 21                     12244  2030763.83   171214.0      77103.0  2042000.86
# 22                      9899  1599464.44   138981.0      62088.0  1607549.21
# 23                      7065  1172625.87    98881.0      44364.0  1179304.44

# %%
z=all_data['Order Time'].unique()
z
# Out:
# array([ 8, 22, 14,  9, 13,  7, 10, 17, 12, 19, 15, 20, 18,  0, 11, 23, 21,
#         4, 16,  5,  2,  1,  6,  3], dtype=int64)

# %%
adtime['Quantity Ordered'].plot(xticks=z,color='r',title='Sales Quantity over the Day',grid=True)

# %%
adtime['Quantity Ordered'].plot.bar(xticks=z,color='c',title='Sales Quantity over the Day',grid=True,legend=True)

# %% [markdown]
# ## Question 4: Which are the most sold together items?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Order Day  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       19.0
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215        7.0
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       30.0
#
#    Order Month   Sales          City   LPin            Location  Order Time
# 0          4.0   23.90        Dallas  75001        Dallas 75001           8
# 2          4.0   99.99        Boston  02215        Boston 02215          22
# 3          4.0  600.00   Los Angeles  90001   Los Angeles 90001          14
# 4          4.0   11.99   Los Angeles  90001   Los Angeles 90001          14
# 5          4.0   11.99   Los Angeles  90001   Los Angeles 90001           9

# %%
dup=all_data[all_data.duplicated(subset=['Order ID'],keep=False)]

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Order Day  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       19.0
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215        7.0
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       30.0
#
#    Order Month   Sales          City   LPin            Location  Order Time
# 0          4.0   23.90        Dallas  75001        Dallas 75001           8
# 2          4.0   99.99        Boston  02215        Boston 02215          22
# 3          4.0  600.00   Los Angeles  90001   Los Angeles 90001          14
# 4          4.0   11.99   Los Angeles  90001   Los Angeles 90001          14
# 5          4.0   11.99   Los Angeles  90001   Los Angeles 90001           9

# %%
dup.head(3)
# Out:
#    Order ID           Product  Quantity Ordered  Price Each  \
# 3    176560      Google Phone                 1      600.00
# 4    176560  Wired Headphones                 1       11.99
# 18   176574      Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Order Day  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       12.0
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001        3.0
#
#     Order Month   Sales          City   LPin            Location  Order Time
# 3           4.0  600.00   Los Angeles  90001   Los Angeles 90001          14
# 4           4.0   11.99   Los Angeles  90001   Los Angeles 90001          14
# 18          4.0  600.00   Los Angeles  90001   Los Angeles 90001          19

# %%
dup['Grouped']=dup.groupby('Order ID')['Product'].transform(lambda x: ",".join(x))
# Out:
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dup[['Grouped','Order ID']].drop_duplicates()
# Out:
#                                                  Grouped Order ID
# 3                          Google Phone,Wired Headphones   176560
# 18                     Google Phone,USB-C Charging Cable   176574
# 30     Bose SoundSport Headphones,Bose SoundSport Hea...   176585
# 32                   AAA Batteries (4-pack),Google Phone   176586
# 119        Lightning Charging Cable,USB-C Charging Cable   176672
# ...                                                  ...      ...
# 11617  Apple Airpods Headphones,Apple Airpods Headphones   259296
# 11619  iPhone,Lightning Charging Cable,Lightning Char...   259297
# 11627       34in Ultrawide Monitor,AA Batteries (4-pack)   259303
# 11639            Wired Headphones,AAA Batteries (4-pack)   259314
# 11677                  Google Phone,USB-C Charging Cable   259350
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

# %%
count=Counter()
for items in dup['Grouped']:
    items_list = items.split(',')
    count.update(Counter(combinations(items_list,2)))

    
print(count)
# Out:
# Counter({('iPhone', 'Lightning Charging Cable'): 2140, ('Google Phone', 'USB-C Charging Cable'): 2116, ('iPhone', 'Wired Headphones'): 987, ('Google Phone', 'Wired Headphones'): 949, ('iPhone', 'Apple Airpods Headphones'): 799, ('Vareebadd Phone', 'USB-C Charging Cable'): 773, ('Google Phone', 'Bose SoundSport Headphones'): 503, ('USB-C Charging Cable', 'Wired Headphones'): 452, ('Vareebadd Phone', 'Wired Headphones'): 327, ('Lightning Charging Cable', 'Wired Headphones'): 253, ('Lightning Charging Cable', 'Apple Airpods Headphones'): 214, ('USB-C Charging Cable', 'Bose SoundSport Headphones'): 211, ('Vareebadd Phone', 'Bose SoundSport Headphones'): 182, ('Apple Airpods Headphones', 'Wired Headphones'): 170, ('Bose SoundSport Headphones', 'Wired Headphones'): 140, ('Lightning Charging Cable', 'USB-C Charging Cable'): 120, ('Lightning Charging Cable', 'AA Batteries (4-pack)'): 114, ('Lightning Charging Cable', 'Lightning Charging Cable'): 111, ('AA Batteries (4-pack)', 'Lightning Charging Cable'): 102, ('AAA Batteries (4-pack)', 'USB-C Charging Cable'): 100, ('Apple Airpods Headphones', 'AAA Batteries (4-pack)'): 99, ('USB-C Charging Cable', 'USB-C Charging Cable'): 99, ('AA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 96, ('AAA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 96, ('Wired Headphones', 'USB-C Charging Cable'): 95, ('USB-C Charging Cable', 'AAA Batteries (4-pack)'): 93, ('AA Batteries (4-pack)', 'Wired Headphones'): 88, ('AAA Batteries (4-pack)', 'Lightning Charging Cable'): 88, ('AAA Batteries (4-pack)', 'Wired Headphones'): 86, ('Wired Headphones', 'AAA Batteries (4-pack)'): 86, ('USB-C Charging Cable', 'Lightning Charging Cable'): 85, ('Wired Headphones', 'AA Batteries (4-pack)'): 83, ('AA Batteries (4-pack)', 'Apple Airpods Headphones'): 82, ('USB-C Charging Cable', 'AA Batteries (4-pack)'): 80, ('AAA Batteries (4-pack)', 'AA Batteries (4-pack)'): 78, ('Lightning Charging Cable', 'Bose SoundSport Headphones'): 78, ('Wired Headphones', 'Lightning Charging Cable'): 75, ('Bose SoundSport Headphones', 'AAA Batteries (4-pack)'): 74, ('AA Batteries (4-pack)', 'USB-C Charging Cable'): 74, ('Lightning Charging Cable', 'AAA Batteries (4-pack)'): 73, ('Wired Headphones', 'Wired Headphones'): 72, ('USB-C Charging Cable', 'Apple Airpods Headphones'): 72, ('Apple Airpods Headphones', 'Lightning Charging Cable'): 70, ('AA Batteries (4-pack)', 'AA Batteries (4-pack)'): 70, ('Bose SoundSport Headphones', 'Lightning Charging Cable'): 67, ('AAA Batteries (4-pack)', 'Apple Airpods Headphones'): 66, ('Wired Headphones', 'Apple Airpods Headphones'): 65, ('USB-C Charging Cable', '27in FHD Monitor'): 65, ('Apple Airpods Headphones', 'Bose SoundSport Headphones'): 65, ('Apple Airpods Headphones', 'USB-C Charging Cable'): 58, ('Apple Airpods Headphones', 'AA Batteries (4-pack)'): 58, ('AA Batteries (4-pack)', 'Bose SoundSport Headphones'): 56, ('Bose SoundSport Headphones', 'Bose SoundSport Headphones'): 54, ('Bose SoundSport Headphones', 'AA Batteries (4-pack)'): 54, ('Bose SoundSport Headphones', 'USB-C Charging Cable'): 50, ('Apple Airpods Headphones', 'Apple Airpods Headphones'): 48, ('AAA Batteries (4-pack)', '27in FHD Monitor'): 44, ('27in FHD Monitor', 'AAA Batteries (4-pack)'): 42, ('Wired Headphones', 'Bose SoundSport Headphones'): 42, ('AAA Batteries (4-pack)', 'Bose SoundSport Headphones'): 40, ('iPhone', 'AAA Batteries (4-pack)'): 38, ('34in Ultrawide Monitor', 'AA Batteries (4-pack)'): 38, ('Lightning Charging Cable', '27in 4K Gaming Monitor'): 37, ('Wired Headphones', '27in 4K Gaming Monitor'): 37, ('Bose SoundSport Headphones', 'Apple Airpods Headphones'): 37, ('Lightning Charging Cable', 'Google Phone'): 36, ('AA Batteries (4-pack)', 'iPhone'): 36, ('27in FHD Monitor', 'Lightning Charging Cable'): 36, ('Lightning Charging Cable', '27in FHD Monitor'): 36, ('34in Ultrawide Monitor', 'Lightning Charging Cable'): 36, ('iPhone', 'USB-C Charging Cable'): 34, ('Wired Headphones', '34in Ultrawide Monitor'): 34, ('Google Pho ...

# %%
for x,y in count.most_common():
    print(x,'-----',y)
    print('_________________________________________')
# Out:
# ('iPhone', 'Lightning Charging Cable') ----- 2140
# _________________________________________
# ('Google Phone', 'USB-C Charging Cable') ----- 2116
# _________________________________________
# ('iPhone', 'Wired Headphones') ----- 987
# _________________________________________
# ('Google Phone', 'Wired Headphones') ----- 949
# _________________________________________
# ('iPhone', 'Apple Airpods Headphones') ----- 799
# _________________________________________
# ('Vareebadd Phone', 'USB-C Charging Cable') ----- 773
# _________________________________________
# ('Google Phone', 'Bose SoundSport Headphones') ----- 503
# _________________________________________
# ('USB-C Charging Cable', 'Wired Headphones') ----- 452
# _________________________________________
# ('Vareebadd Phone', 'Wired Headphones') ----- 327
# _________________________________________
# ('Lightning Charging Cable', 'Wired Headphones') ----- 253
# _________________________________________
# ('Lightning Charging Cable', 'Apple Airpods Headphones') ----- 214
# _________________________________________
# ('USB-C Charging Cable', 'Bose SoundSport Headphones') ----- 211
# _________________________________________
# ('Vareebadd Phone', 'Bose SoundSport Headphones') ----- 182
# _________________________________________
# ('Apple Airpods Headphones', 'Wired Headphones') ----- 170
# _________________________________________
# ('Bose SoundSport Headphones', 'Wired Headphones') ----- 140
# _________________________________________
# ('Lightning Charging Cable', 'USB-C Charging Cable') ----- 120
# _________________________________________
# ('Lightning Charging Cable', 'AA Batteries (4-pack)') ----- 114
# _________________________________________
# ('Lightning Charging Cable', 'Lightning Charging Cable') ----- 111
# _________________________________________
# ('AA Batteries (4-pack)', 'Lightning Charging Cable') ----- 102
# _________________________________________
# ('AAA Batteries (4-pack)', 'USB-C Charging Cable') ----- 100
# _________________________________________
# ('Apple Airpods Headphones', 'AAA Batteries (4-pack)') ----- 99
# _________________________________________
# ('USB-C Charging Cable', 'USB-C Charging Cable') ----- 99
# _________________________________________
# ('AA Batteries (4-pack)', 'AAA Batteries (4-pack)') ----- 96
# _________________________________________
# ('AAA Batteries (4-pack)', 'AAA Batteries (4-pack)') ----- 96
# _________________________________________
# ('Wired Headphones', 'USB-C Charging Cable') ----- 95
# _________________________________________
# ('USB-C Charging Cable', 'AAA Batteries (4-pack)') ----- 93
# _________________________________________
# ('AA Batteries (4-pack)', 'Wired Headphones') ----- 88
# _________________________________________
# ('AAA Batteries (4-pack)', 'Lightning Charging Cable') ----- 88
# _________________________________________
# ('AAA Batteries (4-pack)', 'Wired Headphones') ----- 86
# _________________________________________
# ('Wired Headphones', 'AAA Batteries (4-pack)') ----- 86
# _________________________________________
# ('USB-C Charging Cable', 'Lightning Charging Cable') ----- 85
# _________________________________________
# ('Wired Headphones', 'AA Batteries (4-pack)') ----- 83
# _________________________________________
# ('AA Batteries (4-pack)', 'Apple Airpods Headphones') ----- 82
# _________________________________________
# ('USB-C Charging Cable', 'AA Batteries (4-pack)') ----- 80
# _________________________________________
# ('AAA Batteries (4-pack)', 'AA Batteries (4-pack)') ----- 78
# _________________________________________
# ('Lightning Charging Cable', 'Bose SoundSport Headphones') ----- 78
# _________________________________________
# ('Wired Headphones', 'Lightning Charging Cable') ----- 75
# _________________________________________
# ('Bose SoundSport Headphones', 'AAA Batteries (4-pack)') ----- 74
# _________________________________________
# ('AA Batteries (4-pack)', 'USB-C Charging Cable') ----- 74
# _________________________________________
# ('Lightning Charging Cable', 'AAA Batteries (4-pack)') ----- 73
# _________________________________________
# ('Wired Headphones', 'Wired Headphones') ----- 72
# _________________________________________
# ('USB-C Charging Cable', 'Apple Airpods Headphones') ----- 72
# _________________________________________
# ('Apple Airpods Headphones', 'Lightning Charging Cable') ----- 70
# _________________________________________
# ('AA Batteries (4-pack)', 'AA Batteries (4-pack)') ----- 70
# _________________________________________
# ('Bose SoundSport Headphones', 'Lightning Charging Cable') ----- 67
# _________________________________________
# ('AAA Batteries (4-pack)', 'Apple Airpods Headphones') ----- 66
# _________________________________________
# ('Wired Headphones', 'Apple Airpods Headphones') ----- 65
# _________________________________________
# ('USB-C Charging Cable', '27in FHD Monitor') ----- 65
# _________________________________________
# ('Apple Airpods Headphones', 'Bose SoundSport Headphones') ----- 65
# _________________________________________
# ('Apple Airpods Headphones', 'USB-C Charging Cable') ----- 58
# _________________________________________
# ('Apple Airpods Headphones', 'AA Batteries (4-pack)') ----- 58
# _________________________________________
# ('AA Batteries (4-pack)', 'Bose SoundSport Headphones') ----- 56
# _________________________________________
# ('Bose SoundSport Headphones', 'Bose SoundSport Headphones') ----- 54
# _________________________________________
# ('Bose SoundSport Headphones', 'AA Batteries (4-pack)') ----- 54
# _________________________________________
# ('Bose SoundSport Headphones', 'USB-C Charging Cable') ----- 50
# _________________________________________
# ('Apple Airpods Headphones', 'Apple Airpods Headphones') ----- 48
# _________________________________________
# ('AAA Batteries (4-pack)', '27in FHD Monitor') ----- 44
# _________________________________________
# ('27in FHD Monitor', 'AAA Batteries (4-pack)') ----- 42
# _________________________________________
# ('Wired Headphones', 'Bose SoundSport Headphones') ----- 42
# _________________________________________
# ('AAA Batteries (4-pack)', 'Bose SoundSport Headphones') ----- 40
# _________________________________________
# ('iPhone', 'AAA Batteries (4-pack)') ----- 38
# _________________________________________
# ('34in Ultrawide Monitor', 'AA Batteries (4-pack)') ----- 38
# _________________________________________
# ('Lightning Charging Cable', '27in 4K Gaming Monitor') ----- 37
# _________________________________________
# ('Wired Headphones', '27in 4K Gaming Monitor') ----- 37
# _________________________________________
# ('Bose SoundSport Headphones', 'Apple Airpods Headphones') ----- 37
# _________________________________________
# ('Lightning Charging Cable', 'Google Phone') ----- 36
# _________________________________________
# ('AA Batteries (4-pack)', 'iPhone') ----- 36
# _________________________________________
# ('27in FHD Monitor', 'Lightning Charging Cable') ----- 36
# _________________________________________
# ('Lightning Charging Cable', '27in FHD Monitor') ----- 36
# _________________________________________
# ('34in Ultrawide Monitor', 'Lightning Charging Cable') ----- 36
# _________________________________________
# ('iPhone', 'USB-C Charging Cable') ----- 34
# _________________________________________
# ('Wired Headphones', '34in Ultrawide Monitor') ----- 34
# _________________________________________
# ('Google Phone', 'AA Batteries (4-pack)') ----- 33
# _________________________________________
# ('Wired Headphones', 'iPhone') ----- 33
# _________________________________________
# ('ThinkPad Laptop', 'AAA Batteries (4-pack)') ----- 32
# _________________________________________
# ('27in 4K Gaming Monitor', 'Lightning Charging Cable') ----- 32
# _________________________________________
# ('iPhone', 'AA Batteries (4-pack)') ----- 32
# _________________________________________
# ('Apple Airpods Headphones', 'Google Phone') ----- 31
# _________________________________________
# ('USB-C Charging Cable', 'iPhone') ----- 31
# _________________________________________
# ('Lightning Charging Cable', '34in Ultrawide Monitor') ----- 31
# _________________________________________
# ('34in Ultrawide Monitor', 'USB-C Charging Cable') ----- 30
# _________________________________________
# ('27in FHD Monitor', 'AA Batteries (4-pack)') ----- 30
# _________________________________________
# ('AAA Batteries (4-pack)', '27in 4K Gaming Monitor') ----- 30
# _________________________________________
# ('20in Monitor', 'USB-C Charging Cable') ----- 30
# _________________________________________
# ('Lightning Charging Cable', '20in Monitor') ----- 30
# _________________________________________
# ('27in 4K Gaming Monitor', 'AAA Batteries (4-pack)') ----- 30
# _________________________________________
# ('Bose SoundSport Headphones', '27in FHD Monitor') ----- 29
# _________________________________________
# ('AA Batteries (4-pack)', '27in 4K Gaming Monitor') ----- 28
# _________________________________________
# ('AAA Batteries (4-pack)', 'iPhone') ----- 28
# _________________________________________
# ('Wired Headphones', 'Macbook Pro Laptop') ----- 27
# _________________________________________
# ('AA Batteries (4-pack)', 'Flatscreen TV') ----- 26
# _________________________________________
# ('AA Batteries (4-pack)', '34in Ultrawide Monitor') ----- 26
# _________________________________________
# ('Google Phone', 'Lightning Charging Cable') ----- 26
# _________________________________________
# ('AAA Batteries (4-pack)', '34in Ultrawide Monitor') ----- 26
# _________________________________________
# ('Apple Airpods Headphones', 'iPhone') ----- 26
# _________________________________________
# ('Wired Headphones', '27in FHD Monitor') ----- 26
# _________________________________________
# ('Google Phone', 'AAA Batteries (4-pack)') ----- 25
# _________________________________________
# ('Lightning Charging Cable', 'Flatscreen TV') ----- 25
# _________________________________________
# ('Apple Airpods Headphones', '27in 4K Gaming Monitor') ----- 24
# _________________________________________
# ('Apple Airpods Headphones', '27in FHD Monitor') ----- 24
# _________________________________________
# ('27in FHD Monitor', 'Bose SoundSport Headphones') ----- 24
# _________________________________________
# ('27in FHD Monitor', 'USB-C Charging Cable') ----- 24
# _________________________________________
# ('Bose SoundSport Headphones', '34in Ultrawide Monitor') ----- 24
# _________________________________________
# ('Apple Airpods Headphones', 'Macbook Pro Laptop') ----- 24
# _________________________________________
# ('USB-C Charging Cable', '34in Ultrawide Monitor') ----- 24
# _________________________________________
# ('27in 4K Gaming Monitor', 'USB-C Charging Cable') ----- 24
# _________________________________________
# ('Macbook Pro Laptop', 'USB-C Charging Cable') ----- 24
# _________________________________________
# ('20in Monitor', 'Wired Headphones') ----- 24
# _________________________________________
# ('27in FHD Monitor', 'Apple Airpods Headphones') ----- 24
# _________________________________________
# ('USB-C Charging Cable', 'Google Phone') ----- 24
# _________________________________________
# ('27in 4K Gaming Monitor', 'AA Batteries (4-pack)') ----- 24
# _________________________________________
# ('34in Ultrawide Monitor', 'AAA Batteries (4-pack)') ----- 24
# _________________________________________
# ('AAA Batteries (4-pack)', 'Google Phone') ----- 22
# _________________________________________
# ('AAA Batteries (4-pack)', 'Macbook Pro Laptop') ----- 22
# _________________________________________
# ('USB-C Charging Cable', '27in 4K Gaming Monitor') ----- 22
# _________________________________________
# ('USB-C Charging Cable', 'ThinkPad Laptop') ----- 22
# _________________________________________
# ('34in Ultrawide Monitor', 'Wired Headphones') ----- 22
# _________________________________________
# ('20in Monitor', 'Lightning Charging Cable') ----- 22
# _________________________________________
# ('AA Batteries (4-pack)', '27in FHD Monitor') ----- 22
# _________________________________________
# ('ThinkPad Laptop', 'Lightning Charging Cable') ----- 22
# _________________________________________
# ('Macbook Pro Laptop', 'Lightning Charging Cable') ----- 22
# _________________________________________
# ('AA Batteries (4-pack)', 'Google Phone') ----- 22
# _________________________________________
# ('AAA Batteries (4-pack)', 'ThinkPad Laptop') ----- 22
# _________________________________________
# ('Macbook Pro Laptop', 'Bose SoundSport Headphones') ----- 22
# _________________________________________
# ('27in 4K Gaming Monitor', 'Wired Headphones') ----- 22
# _________________________________________
# ('Flatscreen TV', 'AAA Batteries (4-pack)') ----- 22
# _________________________________________
# ('Wired Headphones', 'Google Phone') ----- 21
# _________________________________________
# ('Lightning Charging Cable', 'iPhone') ----- 21
# _________________________________________
# ('Bose SoundSport Headphones', 'Flatscreen TV') ----- 21
# _________________________________________
# ('Flatscreen TV', 'Lightning Charging Cable') ----- 20
# _________________________________________
# ('Wired Headphones', 'ThinkPad Laptop') ----- 20
# _________________________________________
# ('USB-C Charging Cable', '20in Monitor') ----- 20
# _________________________________________
# ('27in 4K Gaming Monitor', 'Apple Airpods Headphones') ----- 20
# _________________________________________
# ('USB-C Charging Cable', 'Flatscreen TV') ----- 20
# _________________________________________
# ('27in FHD Monitor', 'Wired Headphones') ----- 20
# _________________________________________
# ('AA Batteries (4-pack)', '20in Monitor') ----- 20
# _________________________________________
# ('AAA Batteries (4-pack)', 'Flatscreen TV') ----- 20
# _________________________________________
# ('Lightning Charging Cable', 'Macbook Pro Laptop') ----- 20
# _________________________________________
# ('Bose SoundSport Headphones', '27in 4K Gaming Monitor') ----- 20
# _________________________________________
# ('Apple Airpods Headphones', 'ThinkPad Laptop') ----- 18
# _________________________________________
# ('27in 4K Gaming Monitor', 'Bose SoundSport Headphones') ----- 18
# _________________________________________
# ('20in Monitor', 'Bose SoundSport Headphones') ----- 18
# _________________________________________
# ('Macbook Pro Laptop', 'AA Batteries (4-pack)') ----- 18
# _________________________________________
# ('ThinkPad Laptop', 'USB-C Charging Cable') ----- 18
# _________________________________________
# ('ThinkPad Laptop', 'Bose SoundSport Headphones') ----- 18
# _________________________________________
# ('Vareebadd Phone', 'AA Batteries (4-pack)') ----- 18
# _________________________________________
# ('Google Phone', '27in FHD Monitor') ----- 18
# _________________________________________
# ('USB-C Charging Cable', 'Macbook Pro Laptop') ----- 18
# _________________________________________
# ('27in FHD Monitor', '27in FHD Monitor') ----- 18
# _________________________________________
# ('AA Batteries (4-pack)', 'ThinkPad Laptop') ----- 18
# _________________________________________
# ('Lightning Charging Cable', 'ThinkPad Laptop') ----- 18
# _________________________________________
# ('Google Phone', 'Apple Airpods Headphones') ----- 18
# _________________________________________
# ('AA Batteries (4-pack)', 'Macbook Pro Laptop') ----- 16
# _________________________________________
# ('Flatscreen TV', 'AA Batteries (4-pack)') ----- 16
# _________________________________________
# ('Apple Airpods Headphones', 'Flatscreen TV') ----- 16
# _________________________________________
# ('ThinkPad Laptop', 'AA Batteries (4-pack)') ----- 16
# _________________________________________
# ('AAA Batteries (4-pack)', '20in Monitor') ----- 16
# _________________________________________
# ('34in Ultrawide Monitor', 'Apple Airpods Headphones') ----- 16
# _________________________________________
# ('Bose SoundSport Headphones', 'Google Phone') ----- 16
# _________________________________________
# ('USB-C Charging Cable', 'Vareebadd Phone') ----- 15
# _________________________________________
# ('20in Monitor', 'Apple Airpods Headphones') ----- 14
# _________________________________________
# ('Macbook Pro Laptop', 'Apple Airpods Headphones') ----- 14
# _________________________________________
# ('Wired Headphones', 'Flatscreen TV') ----- 14
# _________________________________________
# ('Wired Headphones', '20in Monitor') ----- 14
# _________________________________________
# ('Macbook Pro Laptop', 'Wired Headphones') ----- 14
# _________________________________________
# ('Vareebadd Phone', 'Apple Airpods Headphones') ----- 14
# _________________________________________
# ('Macbook Pro Laptop', 'AAA Batteries (4-pack)') ----- 14
# _________________________________________
# ('34in Ultrawide Monitor', 'iPhone') ----- 14
# _________________________________________
# ('34in Ultrawide Monitor', '34in Ultrawide Monitor') ----- 14
# _________________________________________
# ('Flatscreen TV', 'USB-C Charging Cable') ----- 14
# _________________________________________
# ('Bose SoundSport Headphones', 'iPhone') ----- 14
# _________________________________________
# ('ThinkPad Laptop', 'Apple Airpods Headphones') ----- 14
# _________________________________________
# ('Macbook Pro Laptop', '27in 4K Gaming Monitor') ----- 14
# _________________________________________
# ('Google Phone', 'iPhone') ----- 14
# _________________________________________
# ('iPhone', '27in 4K Gaming Monitor') ----- 13
# _________________________________________
# ('iPhone', '34in Ultrawide Monitor') ----- 13
# _________________________________________
# ('iPhone', 'Flatscreen TV') ----- 13
# _________________________________________
# ('Flatscreen TV', 'Flatscreen TV') ----- 12
# _________________________________________
# ('Apple Airpods Headphones', '34in Ultrawide Monitor') ----- 12
# _________________________________________
# ('27in 4K Gaming Monitor', '34in Ultrawide Monitor') ----- 12
# _________________________________________
# ('27in 4K Gaming Monitor', 'Macbook Pro Laptop') ----- 12
# _________________________________________
# ('Bose SoundSport Headphones', '20in Monitor') ----- 12
# _________________________________________
# ('Apple Airpods Headphones', '20in Monitor') ----- 12
# _________________________________________
# ('Apple Airpods Headphones', 'Vareebadd Phone') ----- 12
# _________________________________________
# ('Wired Headphones', 'Vareebadd Phone') ----- 12
# _________________________________________
# ('34in Ultrawide Monitor', 'Bose SoundSport Headphones') ----- 12
# _________________________________________
# ('27in FHD Monitor', 'Macbook Pro Laptop') ----- 12
# _________________________________________
# ('20in Monitor', 'AA Batteries (4-pack)') ----- 12
# _________________________________________
# ('iPhone', 'Bose SoundSport Headphones') ----- 11
# _________________________________________
# ('27in 4K Gaming Monitor', '27in 4K Gaming Monitor') ----- 10
# _________________________________________
# ('Flatscreen TV', '34in Ultrawide Monitor') ----- 10
# _________________________________________
# ('27in 4K Gaming Monitor', 'Google Phone') ----- 10
# _________________________________________
# ('27in FHD Monitor', '34in Ultrawide Monitor') ----- 10
# _________________________________________
# ('Flatscreen TV', 'Apple Airpods Headphones') ----- 10
# _________________________________________
# ('iPhone', 'Google Phone') ----- 10
# _________________________________________
# ('34in Ultrawide Monitor', '27in FHD Monitor') ----- 10
# _________________________________________
# ('iPhone', 'Vareebadd Phone') ----- 9
# _________________________________________
# ('Macbook Pro Laptop', '34in Ultrawide Monitor') ----- 8
# _________________________________________
# ('Bose SoundSport Headphones', 'ThinkPad Laptop') ----- 8
# _________________________________________
# ('20in Monitor', 'Macbook Pro Laptop') ----- 8
# _________________________________________
# ('Vareebadd Phone', '34in Ultrawide Monitor') ----- 8
# _________________________________________
# ('Flatscreen TV', 'Wired Headphones') ----- 8
# _________________________________________
# ('Flatscreen TV', '27in FHD Monitor') ----- 8
# _________________________________________
# ('LG Dryer', 'AA Batteries (4-pack)') ----- 8
# _________________________________________
# ('Flatscreen TV', 'Macbook Pro Laptop') ----- 8
# _________________________________________
# ('27in FHD Monitor', '27in 4K Gaming Monitor') ----- 8
# _________________________________________
# ('ThinkPad Laptop', 'Flatscreen TV') ----- 8
# _________________________________________
# ('Flatscreen TV', 'iPhone') ----- 8
# _________________________________________
# ('27in 4K Gaming Monitor', 'ThinkPad Laptop') ----- 8
# _________________________________________
# ('Vareebadd Phone', 'Google Phone') ----- 8
# _________________________________________
# ('Vareebadd Phone', 'iPhone') ----- 8
# _________________________________________
# ('Macbook Pro Laptop', 'Google Phone') ----- 8
# _________________________________________
# ('Google Phone', '34in Ultrawide Monitor') ----- 8
# _________________________________________
# ('27in 4K Gaming Monitor', '27in FHD Monitor') ----- 8
# _________________________________________
# ('Lightning Charging Cable', 'LG Washing Machine') ----- 8
# _________________________________________
# ('27in FHD Monitor', 'ThinkPad Laptop') ----- 8
# _________________________________________
# ('ThinkPad Laptop', 'Wired Headphones') ----- 8
# _________________________________________
# ('iPhone', 'ThinkPad Laptop') ----- 8
# _________________________________________
# ('Bose SoundSport Headphones', 'Macbook Pro Laptop') ----- 8
# _________________________________________
# ('AAA Batteries (4-pack)', 'Vareebadd Phone') ----- 8
# _________________________________________
# ('LG Washing Machine', 'AAA Batteries (4-pack)') ----- 8
# _________________________________________
# ('Lightning Charging Cable', 'Vareebadd Phone') ----- 7
# _________________________________________
# ('Vareebadd Phone', 'Flatscreen TV') ----- 7
# _________________________________________
# ('Google Phone', 'Macbook Pro Laptop') ----- 7
# _________________________________________
# ('Macbook Pro Laptop', 'ThinkPad Laptop') ----- 6
# _________________________________________
# ('ThinkPad Laptop', 'Google Phone') ----- 6
# _________________________________________
# ('34in Ultrawide Monitor', 'Macbook Pro Laptop') ----- 6
# _________________________________________
# ('Google Phone', 'ThinkPad Laptop') ----- 6
# _________________________________________
# ('20in Monitor', '20in Monitor') ----- 6
# _________________________________________
# ('ThinkPad Laptop', 'iPhone') ----- 6
# _________________________________________
# ('34in Ultrawide Monitor', 'Flatscreen TV') ----- 6
# _________________________________________
# ('Macbook Pro Laptop', 'Macbook Pro Laptop') ----- 6
# _________________________________________
# ('34in Ultrawide Monitor', 'ThinkPad Laptop') ----- 6
# _________________________________________
# ('Macbook Pro Laptop', 'iPhone') ----- 6
# _________________________________________
# ('Wired Headphones', 'LG Washing Machine') ----- 6
# _________________________________________
# ('Macbook Pro Laptop', '27in FHD Monitor') ----- 6
# _________________________________________
# ('Flatscreen TV', 'Bose SoundSport Headphones') ----- 6
# _________________________________________
# ('AA Batteries (4-pack)', 'Vareebadd Phone') ----- 6
# _________________________________________
# ('27in FHD Monitor', '20in Monitor') ----- 6
# _________________________________________
# ('27in 4K Gaming Monitor', 'iPhone') ----- 6
# _________________________________________
# ('Google Phone', 'Google Phone') ----- 6
# _________________________________________
# ('Flatscreen TV', 'Google Phone') ----- 6
# _________________________________________
# ('27in 4K Gaming Monitor', 'Flatscreen TV') ----- 6
# _________________________________________
# ('Apple Airpods Headphones', 'LG Dryer') ----- 6
# _________________________________________
# ('20in Monitor', 'AAA Batteries (4-pack)') ----- 6
# _________________________________________
# ('iPhone', 'Macbook Pro Laptop') ----- 6
# _________________________________________
# ('iPhone', 'iPhone') ----- 5
# _________________________________________
# ('Vareebadd Phone', '27in 4K Gaming Monitor') ----- 5
# _________________________________________
# ('34in Ultrawide Monitor', 'Google Phone') ----- 4
# _________________________________________
# ('Macbook Pro Laptop', '20in Monitor') ----- 4
# _________________________________________
# ('Lightning Charging Cable', 'LG Dryer') ----- 4
# _________________________________________
# ('Flatscreen TV', '27in 4K Gaming Monitor') ----- 4
# _________________________________________
# ('ThinkPad Laptop', 'Macbook Pro Laptop') ----- 4
# _________________________________________
# ('Macbook Pro Laptop', 'LG Washing Machine') ----- 4
# _________________________________________
# ('20in Monitor', '27in FHD Monitor') ----- 4
# _________________________________________
# ('ThinkPad Laptop', 'ThinkPad Laptop') ----- 4
# _________________________________________
# ('Bose SoundSport Headphones', 'Vareebadd Phone') ----- 4
# _________________________________________
# ('Vareebadd Phone', 'ThinkPad Laptop') ----- 4
# _________________________________________
# ('20in Monitor', 'ThinkPad Laptop') ----- 4
# _________________________________________
# ('27in FHD Monitor', 'LG Dryer') ----- 4
# _________________________________________
# ('27in 4K Gaming Monitor', '20in Monitor') ----- 4
# _________________________________________
# ('LG Washing Machine', 'Lightning Charging Cable') ----- 4
# _________________________________________
# ('LG Washing Machine', 'Bose SoundSport Headphones') ----- 4
# _________________________________________
# ('AA Batteries (4-pack)', 'LG Dryer') ----- 4
# _________________________________________
# ('Vareebadd Phone', 'AAA Batteries (4-pack)') ----- 4
# _________________________________________
# ('iPhone', '20in Monitor') ----- 4
# _________________________________________
# ('20in Monitor', 'Google Phone') ----- 4
# _________________________________________
# ('Flatscreen TV', 'ThinkPad Laptop') ----- 4
# _________________________________________
# ('ThinkPad Laptop', '27in FHD Monitor') ----- 4
# _________________________________________
# ('27in FHD Monitor', 'Flatscreen TV') ----- 4
# _________________________________________
# ('Google Phone', '20in Monitor') ----- 4
# _________________________________________
# ('Google Phone', 'Vareebadd Phone') ----- 3
# _________________________________________
# ('27in 4K Gaming Monitor', 'Vareebadd Phone') ----- 2
# _________________________________________
# ('27in FHD Monitor', 'iPhone') ----- 2
# _________________________________________
# ('Vareebadd Phone', 'Lightning Charging Cable') ----- 2
# _________________________________________
# ('20in Monitor', 'iPhone') ----- 2
# _________________________________________
# ('LG Dryer', 'Vareebadd Phone') ----- 2
# _________________________________________
# ('Macbook Pro Laptop', 'Flatscreen TV') ----- 2
# _________________________________________
# ('ThinkPad Laptop', 'Vareebadd Phone') ----- 2
# _________________________________________
# ('Google Phone', 'Flatscreen TV') ----- 2
# _________________________________________
# ('LG Washing Machine', 'Google Phone') ----- 2
# _________________________________________
# ('LG Washing Machine', 'Wired Headphones') ----- 2
# _________________________________________
# ('LG Dryer', 'Flatscreen TV') ----- 2
# _________________________________________
# ('27in FHD Monitor', 'LG Washing Machine') ----- 2
# _________________________________________
# ('LG Dryer', '27in FHD Monitor') ----- 2
# _________________________________________
# ('20in Monitor', '34in Ultrawide Monitor') ----- 2
# _________________________________________
# ('34in Ultrawide Monitor', '20in Monitor') ----- 2
# _________________________________________
# ('34in Ultrawide Monitor', 'LG Washing Machine') ----- 2
# _________________________________________
# ('Google Phone', '27in 4K Gaming Monitor') ----- 2
# _________________________________________
# ('LG Washing Machine', 'iPhone') ----- 2
# _________________________________________
# ('LG Dryer', 'Wired Headphones') ----- 2
# _________________________________________
# ('27in FHD Monitor', 'Vareebadd Phone') ----- 2
# _________________________________________
# ('LG Washing Machine', '27in 4K Gaming Monitor') ----- 2
# _________________________________________
# ('LG Washing Machine', 'Apple Airpods Headphones') ----- 2
# _________________________________________
# ('27in 4K Gaming Monitor', 'LG Dryer') ----- 2
# _________________________________________
# ('20in Monitor', 'LG Washing Machine') ----- 2
# _________________________________________
# ('LG Dryer', 'Google Phone') ----- 2
# _________________________________________
# ('Vareebadd Phone', '27in FHD Monitor') ----- 2
# _________________________________________
# ('ThinkPad Laptop', '27in 4K Gaming Monitor') ----- 2
# _________________________________________
# ('20in Monitor', 'Flatscreen TV') ----- 2
# _________________________________________
# ('USB-C Charging Cable', 'LG Dryer') ----- 2
# _________________________________________
# ('LG Washing Machine', '20in Monitor') ----- 2
# _________________________________________
# ('Flatscreen TV', '20in Monitor') ----- 2
# _________________________________________
# ('27in FHD Monitor', 'Google Phone') ----- 2
# _________________________________________
# ('iPhone', '27in FHD Monitor') ----- 2
# _________________________________________
# ('LG Dryer', 'AAA Batteries (4-pack)') ----- 2
# _________________________________________
# ('ThinkPad Laptop', '34in Ultrawide Monitor') ----- 2
# _________________________________________
# ('iPhone', 'LG Washing Machine') ----- 2
# _________________________________________
# ('AAA Batteries (4-pack)', 'LG Dryer') ----- 2
# _________________________________________
# ('LG Dryer', '27in 4K Gaming Monitor') ----- 2
# _________________________________________
# ('LG Dryer', 'Lightning Charging Cable') ----- 2
# _________________________________________
# ('ThinkPad Laptop', 'LG Dryer') ----- 2
# _________________________________________
# ('LG Washing Machine', 'AA Batteries (4-pack)') ----- 2
# _________________________________________

# %% [markdown]
# # Question 5: What product sold the most? And Why do you think it sold the most?

# %%
Psales=all_data[['Product','Quantity Ordered','Price Each']].groupby('Product').sum(ascending=False).sort_values('Quantity Ordered')

# %%
Psales=all_data[['Product','Quantity Ordered','Price Each']].groupby('Product').agg({'Quantity Ordered':'sum','Price Each':'mean'}).sort_values('Quantity Ordered')

# %%
import altair as alt

# %%
Psales.head()
# Out:
#                     Quantity Ordered  Price Each
# Product
# LG Dryer                         646      600.00
# LG Washing Machine               666      600.00
# Vareebadd Phone                 2068      400.00
# 20in Monitor                    4129      109.99
# ThinkPad Laptop                 4130      999.99

# %%
Psales.index
# Out:
# Index(['LG Dryer', 'LG Washing Machine', 'Vareebadd Phone', '20in Monitor',
#        'ThinkPad Laptop', 'Macbook Pro Laptop', 'Flatscreen TV',
#        'Google Phone', '34in Ultrawide Monitor', '27in 4K Gaming Monitor',
#        'iPhone', '27in FHD Monitor', 'Bose SoundSport Headphones',
#        'Apple Airpods Headphones', 'Wired Headphones',
#        'Lightning Charging Cable', 'USB-C Charging Cable',
#        'AA Batteries (4-pack)', 'AAA Batteries (4-pack)'],
#       dtype='object', name='Product')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax=plt.subplots(2,3)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-04d92a313600> in <module>
# ----> 1 plt.hist(Psales['Quantity Ordered'],Psales.index)
#
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6773             # this will automatically overwrite bins,
#    6774             # so that each histogram uses the same bins
# -> 6775             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6776             m = m.astype(float)  # causes problems later if it's an int
#    6777             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     783     a, weights = _ravel_and_check_weights(a, weights)
#     784
# --> 785     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     786
#     787     # Histogram is an integer or a float array depending on the weights.
#
# c:\users\bipin\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     423         if np.any(bin_edges[:-1] > bin_edges[1:]):
#     424             raise ValueError(
# --> 425                 '`bins` must increase monotonically, when an array')
#     426
#     427     else:
#
# ValueError: `bins` must increase monotonically, when an array
